# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
modeling_data = pd.read_csv("../data/processed/f1_modeling_dataset.csv")

modeling_data.head()
# Out:
#    raceId  driverId     driver_name  constructorId name_constructor  \
# 0      36         1  Lewis Hamilton              1          McLaren
# 1      37         1  Lewis Hamilton              1          McLaren
# 2      38         1  Lewis Hamilton              1          McLaren
# 3      39         1  Lewis Hamilton              1          McLaren
# 4      40         1  Lewis Hamilton              1          McLaren
#
#    circuitId  year  round  grid  qualifying_position  \
# 0          1  2007      1     4                  4.0
# 1          2  2007      2     4                  4.0
# 2          3  2007      3     2                  2.0
# 3          4  2007      4     4                  4.0
# 4          6  2007      5     2                  2.0
#
#    driver_points_before_race  driver_standing_before_race  \
# 0                        0.0                         99.0
# 1                        6.0                          3.0
# 2                       14.0                          3.0
# 3                       22.0                          3.0
# 4                       30.0                          1.0
#
#    driver_wins_before_race  constructor_points_before_race  \
# 0                      0.0                             0.0
# 1                      0.0                            14.0
# 2                      0.0                            32.0
# 3                      0.0                            44.0
# 4                      0.0                            58.0
#
#    constructor_standing_before_race  constructor_wins_before_race  podium  \
# 0                              99.0                           0.0       1
# 1                              11.0                           0.0       1
# 2                              11.0                           1.0       1
# 3                              11.0                           1.0       1
# 4                              11.0                           1.0       1
#
#    positionOrder
# 0              3
# 1              2
# 2              2
# 3              2
# 4              2

# %%
modeling_data.shape
# Out:
# (10484, 18)

# %%
results_df = pd.read_csv("../data/processed/model_experiment_results.csv")

results_df.sort_values("roc_auc", ascending=False).head()
# Out:
#             feature_set                model  accuracy  precision    recall  \
# 8        driver_history    Gradient Boosting  0.923141   0.761905  0.711111
# 14   all_valid_features    Gradient Boosting  0.910610   0.735484  0.633333
# 11  constructor_history    Gradient Boosting  0.905597   0.721854  0.605556
# 12   all_valid_features  Logistic Regression  0.902256   0.752000  0.522222
# 6        driver_history  Logistic Regression  0.904762   0.732394  0.577778
#
#           f1   roc_auc
# 8   0.735632  0.934207
# 14  0.680597  0.931888
# 11  0.658610  0.926521
# 12  0.616393  0.925904
# 6   0.645963  0.925563

# %% [markdown]
# # Driver history

# %%
best_features = [
    "grid",
    "qualifying_position",
    "driver_points_before_race",
    "driver_standing_before_race",
    "driver_wins_before_race"
]

# %%
train = modeling_data[modeling_data["year"] <= 2018]

val = modeling_data[
    (modeling_data["year"] >= 2019) &
    (modeling_data["year"] <= 2021)
]

test = modeling_data[modeling_data["year"] >= 2022]

# %%
print("Train:", train.shape)
print("Validation:", val.shape)
print("Test:", test.shape)
# Out:
# Train: (7928, 18)
# Validation: (1197, 18)
# Test: (1359, 18)

# %%
X_train = train[best_features]
Y_train = train["podium"]

X_val = val[best_features]
Y_val = val["podium"]

X_test = test[best_features]
Y_test = test["podium"]

# %% [markdown]
# ## Tuning the model

# %%
results = []
n_estimators_list = [50, 100, 200]
learning_rate_list = [0.01, 0.05, 0.1]
max_depth_list = [1, 2, 3]

# %%
for n in n_estimators_list:
    
    for rate in learning_rate_list:
        
        for depth in max_depth_list:
            
            model = GradientBoostingClassifier(
                n_estimators=n,
                learning_rate=rate,
                max_depth=depth,
                random_state=42
            )
            
            model.fit(X_train, Y_train)
            
            val_preds = model.predict(X_val)
            val_probs = model.predict_proba(X_val)[:, 1]
            
            results.append({
                "n_estimators": n,
                "learning_rate": rate,
                "max_depth": depth,
                "accuracy": accuracy_score(Y_val, val_preds),
                "precision": precision_score(Y_val, val_preds, zero_division=0),
                "recall": recall_score(Y_val, val_preds, zero_division=0),
                "f1": f1_score(Y_val, val_preds, zero_division=0),
                "roc_auc": roc_auc_score(Y_val, val_probs)
            })

# %%
tuning_df = pd.DataFrame(results)

tuning_df.sort_values("roc_auc", ascending=False).head(10)
# Out:
#     n_estimators  learning_rate  max_depth  accuracy  precision    recall  \
# 13           100           0.05          2  0.919799   0.762500  0.677778
# 14           100           0.05          3  0.923141   0.761905  0.711111
# 15           100           0.10          1  0.916458   0.738095  0.688889
# 7             50           0.10          2  0.918129   0.750000  0.683333
# 24           200           0.10          1  0.915622   0.730994  0.694444
# 8             50           0.10          3  0.922306   0.757396  0.711111
# 5             50           0.05          3  0.916458   0.756410  0.655556
# 21           200           0.05          1  0.915622   0.733728  0.688889
# 23           200           0.05          3  0.922306   0.754386  0.716667
# 17           100           0.10          3  0.923141   0.761905  0.711111
#
#           f1   roc_auc
# 13  0.717647  0.936188
# 14  0.735632  0.935977
# 15  0.712644  0.935598
# 7   0.715116  0.935521
# 24  0.712251  0.935502
# 8   0.733524  0.935385
# 5   0.702381  0.935133
# 21  0.710602  0.934743
# 23  0.735043  0.934349
# 17  0.735632  0.934207

# %%
tuning_df.to_csv("../data/processed/gradient_boosting_tuning_results.csv", index=False)

# %%
best_row = tuning_df.sort_values("roc_auc", ascending=False).iloc[0]

best_n_estimators = int(best_row["n_estimators"])
best_learning_rate = best_row["learning_rate"]
best_max_depth = int(best_row["max_depth"])

# %% [markdown]
# ## Final model

# %%
train_val = pd.concat([train, val])

X_train_val = train_val[best_features]
Y_train_val = train_val["podium"]

final_model = GradientBoostingClassifier(
    n_estimators=best_n_estimators,
    learning_rate=best_learning_rate,
    max_depth=best_max_depth,
    random_state=42
)

final_model.fit(X_train_val, Y_train_val)
# Out:
# GradientBoostingClassifier(learning_rate=np.float64(0.05), max_depth=2,
#                            random_state=42)

# %% [markdown]
# ### Evaluate

# %%
test_preds = final_model.predict(X_test)
test_probs = final_model.predict_proba(X_test)[:, 1]

# %%
test_accuracy = accuracy_score(Y_test, test_preds)
test_precision = precision_score(Y_test, test_preds, zero_division=0)
test_recall = recall_score(Y_test, test_preds, zero_division=0)
test_f1 = f1_score(Y_test, test_preds, zero_division=0)
test_auc = roc_auc_score(Y_test, test_probs)

print("Final Test Results")
print("Accuracy:", test_accuracy)
print("Precision:", test_precision)
print("Recall:", test_recall)
print("F1 Score:", test_f1)
print("ROC-AUC:", test_auc)
# Out:
# Final Test Results
# Accuracy: 0.8991905813097866
# Precision: 0.710691823899371
# Recall: 0.553921568627451
# F1 Score: 0.6225895316804407
# ROC-AUC: 0.9364166878872761

# %%
cm = confusion_matrix(Y_test, test_preds)

plt.figure(figsize=(5,4))

sns.heatmap(cm, annot=True, fmt="d")

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ### Look at the import

# %%
importance_df = pd.DataFrame({
    "feature": best_features,
    "importance": final_model.feature_importances_
})

importance_df = importance_df.sort_values("importance", ascending=False)

plt.figure(figsize=(8,4))

sns.barplot(
    data=importance_df,
    x="importance",
    y="feature"
)

plt.title("Feature Importance for Final Gradient Boosting Model")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# ## Race-level podium prediction

# %%
test_with_preds = test.copy()

test_with_preds["podium_probability"] = test_probs
test_with_preds["predicted_podium"] = test_preds

# %%
predicted_top3 = (
    test_with_preds
    .sort_values(["raceId", "podium_probability"], ascending=[True, False])
    .groupby("raceId")
    .head(3)
)

predicted_top3.head()
# Out:
#       raceId  driverId      driver_name  constructorId name_constructor  \
# 9631    1074       844  Charles Leclerc              6          Ferrari
# 8532    1074       830   Max Verstappen              9         Red Bull
# 8780    1074       832     Carlos Sainz              6          Ferrari
# 9632    1075       844  Charles Leclerc              6          Ferrari
# 8781    1075       832     Carlos Sainz              6          Ferrari
#
#       circuitId  year  round  grid  qualifying_position  \
# 9631          3  2022      1     1                  1.0
# 8532          3  2022      1     2                  2.0
# 8780          3  2022      1     3                  3.0
# 9632         77  2022      2     2                  2.0
# 8781         77  2022      2     3                  3.0
#
#       driver_points_before_race  driver_standing_before_race  \
# 9631                        0.0                         99.0
# 8532                        0.0                         99.0
# 8780                        0.0                         99.0
# 9632                       26.0                          1.0
# 8781                       18.0                          2.0
#
#       driver_wins_before_race  constructor_points_before_race  \
# 9631                      0.0                             0.0
# 8532                      0.0                             0.0
# 8780                      0.0                             0.0
# 9632                      1.0                            44.0
# 8781                      0.0                            44.0
#
#       constructor_standing_before_race  constructor_wins_before_race  podium  \
# 9631                              99.0                           0.0       1
# 8532                              99.0                           0.0       0
# 8780                              99.0                           0.0       1
# 9632                               1.0                           1.0       1
# 8781                               1.0                           1.0       1
#
#       positionOrder  podium_probability  predicted_podium
# 9631              1            0.653862                 1
# 8532             19            0.532347                 1
# 8780              2            0.446499                 0
# 9632              2            0.693897                 1
# 8781              3            0.630252                 1

# %%
race_scores = (
    predicted_top3
    .groupby("raceId")["podium"]
    .sum()
    .reset_index()
)

race_scores = race_scores.rename(columns={"podium": "actual_podiums_found"})

race_scores.head()
# Out:
#    raceId  actual_podiums_found
# 0    1074                     2
# 1    1075                     2
# 2    1076                     2
# 3    1077                     2
# 4    1078                     3

# %%
race_scores["actual_podiums_found"].mean()
# Out:
# np.float64(1.9264705882352942)

# %%
final_results = pd.DataFrame([{
    "model": "Tuned Gradient Boosting",
    "feature_set": "driver_history",
    "accuracy": test_accuracy,
    "precision": test_precision,
    "recall": test_recall,
    "f1": test_f1,
    "roc_auc": test_auc,
    "avg_actual_podiums_found_per_race": race_scores["actual_podiums_found"].mean()
}])

final_results
# Out:
#                      model     feature_set  accuracy  precision    recall  \
# 0  Tuned Gradient Boosting  driver_history  0.899191   0.710692  0.553922
#
#         f1   roc_auc  avg_actual_podiums_found_per_race
# 0  0.62259  0.936417                           1.926471

# %%
final_results.to_csv("../data/processed/final_model_test_results.csv", index=False)

# %% [markdown]
# ## Predict for One race

# %%
race_id = 1075

specific_race = test_with_preds[test_with_preds["raceId"] == race_id].copy()

specific_race_predictions = specific_race.sort_values(
    "podium_probability",
    ascending=False
)

specific_race_predictions[[
    "raceId",
    "year",
    "round",
    "driver_name",
    "name_constructor",
    "grid",
    "qualifying_position",
    "podium_probability",
    "predicted_podium",
    "podium",
]].head(10)
# Out:
#       raceId  year  round      driver_name name_constructor  grid  \
# 9632    1075  2022      2  Charles Leclerc          Ferrari     2
# 8781    1075  2022      2     Carlos Sainz          Ferrari     3
# 7150    1075  2022      2     Sergio Pérez         Red Bull     1
# 8533    1075  2022      2   Max Verstappen         Red Bull     4
# 9909    1075  2022      2   George Russell         Mercedes     6
# 9077    1075  2022      2     Esteban Ocon   Alpine F1 Team     5
# 8104    1075  2022      2  Kevin Magnussen     Haas F1 Team    10
# 7864    1075  2022      2  Valtteri Bottas       Alfa Romeo     8
# 289     1075  2022      2   Lewis Hamilton         Mercedes    15
# 1022    1075  2022      2  Fernando Alonso   Alpine F1 Team     7
#
#       qualifying_position  podium_probability  predicted_podium  podium
# 9632                  2.0            0.693897                 1       1
# 8781                  3.0            0.630252                 1       1
# 7150                  1.0            0.522064                 1       0
# 8533                  4.0            0.206494                 0       1
# 9909                  6.0            0.189518                 0       0
# 9077                  5.0            0.138294                 0       0
# 8104                 10.0            0.077488                 0       0
# 7864                  8.0            0.057057                 0       0
# 289                  16.0            0.053064                 0       0
# 1022                  7.0            0.050291                 0       0

# %%
predicted_podium = specific_race_predictions.head(3)[[
    "driver_name",
    "name_constructor",
    "podium_probability",
    "positionOrder"
]]

actual_podium = specific_race_predictions[
    specific_race_predictions["podium"] == 1
][[
    "driver_name",
    "name_constructor",
    "podium_probability",
    "positionOrder"
]].sort_values("positionOrder")

print("Predicted Podium:")
display(predicted_podium)

print("Actual Podium:")
display(actual_podium)
# Out:
# Predicted Podium:
#           driver_name name_constructor  podium_probability  positionOrder
# 9632  Charles Leclerc          Ferrari            0.693897              2
# 8781     Carlos Sainz          Ferrari            0.630252              3
# 7150     Sergio Pérez         Red Bull            0.522064              4
# Actual Podium:
#           driver_name name_constructor  podium_probability  positionOrder
# 8533   Max Verstappen         Red Bull            0.206494              1
# 9632  Charles Leclerc          Ferrari            0.693897              2
# 8781     Carlos Sainz          Ferrari            0.630252              3

# %% [markdown]
# ## Row level podium accuracy

# %%
(test_with_preds["predicted_podium"] == test_with_preds["podium"]).mean()
# Out:
# np.float64(0.8991905813097866)

# %% [markdown]
# ## Race level podium accuracy

# %%
predicted_top3 = (
    test_with_preds
    .sort_values(["raceId", "podium_probability"], ascending=[True, False])
    .groupby("raceId")
    .head(3)
)

# %%
race_scores = (
    predicted_top3
    .groupby("raceId")["podium"]
    .sum()
    .reset_index()
)

race_scores = race_scores.rename(columns={"podium": "actual_podiums_found"})

race_scores.head()
# Out:
#    raceId  actual_podiums_found
# 0    1074                     2
# 1    1075                     2
# 2    1076                     2
# 3    1077                     2
# 4    1078                     3

# %%
race_scores["actual_podiums_found"].mean() / 3
# Out:
# np.float64(0.6421568627450981)

# %%
total_correct = race_scores["actual_podiums_found"].sum()
total_possible = len(race_scores) * 3

print("Total correct podium picks:", total_correct)
print("Total possible podium picks:", total_possible)
print("Percent correct:", total_correct / total_possible)
# Out:
# Total correct podium picks: 131
# Total possible podium picks: 204
# Percent correct: 0.6421568627450981

# %%
race_scores["actual_podiums_found"].value_counts().sort_index()
# Out:
# actual_podiums_found
# 1    17
# 2    39
# 3    12
# Name: count, dtype: int64

# %% [markdown]
# 64.2% of podium slots correctly identified

# %% [markdown]
# # Driver and Constructor History

# %%
best_features = [
    "grid",
    "qualifying_position",
    "driver_points_before_race",
    "driver_standing_before_race",
    "driver_wins_before_race",
    "constructor_points_before_race",
    "constructor_standing_before_race",
    "constructor_wins_before_race"
]

# %%
X_train = train[best_features]
Y_train = train["podium"]

X_val = val[best_features]
Y_val = val["podium"]

X_test = test[best_features]
Y_test = test["podium"]

# %% [markdown]
# ## Tuning

# %%
results = []
n_estimators_list = [50, 100, 200]
learning_rate_list = [0.01, 0.05, 0.1]
max_depth_list = [1, 2, 3]

# %%
for n in n_estimators_list:
    
    for rate in learning_rate_list:
        
        for depth in max_depth_list:
            
            model = GradientBoostingClassifier(
                n_estimators=n,
                learning_rate=rate,
                max_depth=depth,
                random_state=42
            )
            
            model.fit(X_train, Y_train)
            
            val_preds = model.predict(X_val)
            val_probs = model.predict_proba(X_val)[:, 1]
            
            results.append({
                "n_estimators": n,
                "learning_rate": rate,
                "max_depth": depth,
                "accuracy": accuracy_score(Y_val, val_preds),
                "precision": precision_score(Y_val, val_preds, zero_division=0),
                "recall": recall_score(Y_val, val_preds, zero_division=0),
                "f1": f1_score(Y_val, val_preds, zero_division=0),
                "roc_auc": roc_auc_score(Y_val, val_probs)
            })

# %%
new_tuning_df = pd.DataFrame(results)

new_tuning_df.sort_values("roc_auc", ascending=False).head(10)
# Out:
#     n_estimators  learning_rate  max_depth  accuracy  precision    recall  \
# 5             50           0.05          3  0.913952   0.754967  0.633333
# 22           200           0.05          2  0.914787   0.746835  0.655556
# 11           100           0.01          3  0.887218   0.835821  0.311111
# 20           200           0.01          3  0.911445   0.753425  0.611111
# 14           100           0.05          3  0.916458   0.753165  0.661111
# 15           100           0.10          1  0.914787   0.729412  0.688889
# 8             50           0.10          3  0.918964   0.764331  0.666667
# 16           100           0.10          2  0.918129   0.759494  0.666667
# 24           200           0.10          1  0.913952   0.722543  0.694444
# 21           200           0.05          1  0.916458   0.735294  0.694444
#
#           f1   roc_auc
# 5   0.688822  0.935191
# 22  0.698225  0.934868
# 11  0.453441  0.934598
# 20  0.674847  0.934415
# 14  0.704142  0.934186
# 15  0.708571  0.934043
# 8   0.712166  0.933885
# 16  0.710059  0.933776
# 24  0.708215  0.933762
# 21  0.714286  0.933454

# %%
new_tuning_df.to_csv("../data/processed/driver_const_gradient_boosting_tuning_results.csv", index=False)

# %%
best_row = new_tuning_df.sort_values("roc_auc", ascending=False).iloc[0]

best_n_estimators = int(best_row["n_estimators"])
best_learning_rate = best_row["learning_rate"]
best_max_depth = int(best_row["max_depth"])

# %% [markdown]
# ## Final Model

# %%
train_val = pd.concat([train, val])

X_train_val = train_val[best_features]
Y_train_val = train_val["podium"]

final_model = GradientBoostingClassifier(
    n_estimators=best_n_estimators,
    learning_rate=best_learning_rate,
    max_depth=best_max_depth,
    random_state=42
)

final_model.fit(X_train_val, Y_train_val)
# Out:
# GradientBoostingClassifier(learning_rate=np.float64(0.05), n_estimators=50,
#                            random_state=42)

# %%
test_preds = final_model.predict(X_test)
test_probs = final_model.predict_proba(X_test)[:, 1]

# %%
test_accuracy = accuracy_score(Y_test, test_preds)
test_precision = precision_score(Y_test, test_preds, zero_division=0)
test_recall = recall_score(Y_test, test_preds, zero_division=0)
test_f1 = f1_score(Y_test, test_preds, zero_division=0)
test_auc = roc_auc_score(Y_test, test_probs)

print("Final Test Results")
print("Accuracy:", test_accuracy)
print("Precision:", test_precision)
print("Recall:", test_recall)
print("F1 Score:", test_f1)
print("ROC-AUC:", test_auc)
# Out:
# Final Test Results
# Accuracy: 0.8977189109639441
# Precision: 0.7096774193548387
# Recall: 0.5392156862745098
# F1 Score: 0.6128133704735376
# ROC-AUC: 0.9332442067736186

# %%
cm = confusion_matrix(Y_test, test_preds)

plt.figure(figsize=(5,4))

sns.heatmap(cm, annot=True, fmt="d")

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
importance_df = pd.DataFrame({
    "feature": best_features,
    "importance": final_model.feature_importances_
})

importance_df = importance_df.sort_values("importance", ascending=False)

plt.figure(figsize=(8,4))

sns.barplot(
    data=importance_df,
    x="importance",
    y="feature"
)

plt.title("Feature Importance for Final Gradient Boosting Model")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# ## Race-level podium prediction

# %%
test_with_preds = test.copy()

test_with_preds["podium_probability"] = test_probs
test_with_preds["predicted_podium"] = test_preds

# %%
predicted_top3 = (
    test_with_preds
    .sort_values(["raceId", "podium_probability"], ascending=[True, False])
    .groupby("raceId")
    .head(3)
)

predicted_top3.head()
# Out:
#       raceId  driverId      driver_name  constructorId name_constructor  \
# 9631    1074       844  Charles Leclerc              6          Ferrari
# 8532    1074       830   Max Verstappen              9         Red Bull
# 8780    1074       832     Carlos Sainz              6          Ferrari
# 9632    1075       844  Charles Leclerc              6          Ferrari
# 8781    1075       832     Carlos Sainz              6          Ferrari
#
#       circuitId  year  round  grid  qualifying_position  \
# 9631          3  2022      1     1                  1.0
# 8532          3  2022      1     2                  2.0
# 8780          3  2022      1     3                  3.0
# 9632         77  2022      2     2                  2.0
# 8781         77  2022      2     3                  3.0
#
#       driver_points_before_race  driver_standing_before_race  \
# 9631                        0.0                         99.0
# 8532                        0.0                         99.0
# 8780                        0.0                         99.0
# 9632                       26.0                          1.0
# 8781                       18.0                          2.0
#
#       driver_wins_before_race  constructor_points_before_race  \
# 9631                      0.0                             0.0
# 8532                      0.0                             0.0
# 8780                      0.0                             0.0
# 9632                      1.0                            44.0
# 8781                      0.0                            44.0
#
#       constructor_standing_before_race  constructor_wins_before_race  podium  \
# 9631                              99.0                           0.0       1
# 8532                              99.0                           0.0       0
# 8780                              99.0                           0.0       1
# 9632                               1.0                           1.0       1
# 8781                               1.0                           1.0       1
#
#       positionOrder  podium_probability  predicted_podium
# 9631              1            0.582847                 1
# 8532             19            0.494278                 0
# 8780              2            0.411523                 0
# 9632              2            0.660849                 1
# 8781              3            0.577183                 1

# %%
race_scores = (
    predicted_top3
    .groupby("raceId")["podium"]
    .sum()
    .reset_index()
)

race_scores = race_scores.rename(columns={"podium": "actual_podiums_found"})

race_scores.head()
# Out:
#    raceId  actual_podiums_found
# 0    1074                     2
# 1    1075                     2
# 2    1076                     2
# 3    1077                     2
# 4    1078                     3

# %%
race_scores["actual_podiums_found"].mean()
# Out:
# np.float64(1.8970588235294117)

# %%
final_results = pd.DataFrame([{
    "model": "Tuned Gradient Boosting",
    "feature_set": "driver_constructor_history",
    "accuracy": test_accuracy,
    "precision": test_precision,
    "recall": test_recall,
    "f1": test_f1,
    "roc_auc": test_auc,
    "avg_actual_podiums_found_per_race": race_scores["actual_podiums_found"].mean()
}])

final_results
# Out:
#                      model                 feature_set  accuracy  precision  \
# 0  Tuned Gradient Boosting  driver_constructor_history  0.897719   0.709677
#
#      recall        f1   roc_auc  avg_actual_podiums_found_per_race
# 0  0.539216  0.612813  0.933244                           1.897059

# %%
final_results.to_csv("../data/processed/driver_const_final_model_test_results.csv", index=False)

# %%
race_id = 1075

specific_race = test_with_preds[test_with_preds["raceId"] == race_id].copy()

specific_race_predictions = specific_race.sort_values(
    "podium_probability",
    ascending=False
)

specific_race_predictions[[
    "raceId",
    "year",
    "round",
    "driver_name",
    "name_constructor",
    "grid",
    "qualifying_position",
    "podium_probability",
    "predicted_podium",
    "podium",
]].head(10)
# Out:
#        raceId  year  round      driver_name name_constructor  grid  \
# 9632     1075  2022      2  Charles Leclerc          Ferrari     2
# 8781     1075  2022      2     Carlos Sainz          Ferrari     3
# 7150     1075  2022      2     Sergio Pérez         Red Bull     1
# 8533     1075  2022      2   Max Verstappen         Red Bull     4
# 9909     1075  2022      2   George Russell         Mercedes     6
# 9077     1075  2022      2     Esteban Ocon   Alpine F1 Team     5
# 8104     1075  2022      2  Kevin Magnussen     Haas F1 Team    10
# 10278    1075  2022      2  Mick Schumacher     Haas F1 Team     0
# 289      1075  2022      2   Lewis Hamilton         Mercedes    15
# 7864     1075  2022      2  Valtteri Bottas       Alfa Romeo     8
#
#        qualifying_position  podium_probability  predicted_podium  podium
# 9632                   2.0            0.660849                 1       1
# 8781                   3.0            0.577183                 1       1
# 7150                   1.0            0.463069                 0       0
# 8533                   4.0            0.190735                 0       1
# 9909                   6.0            0.175195                 0       0
# 9077                   5.0            0.104068                 0       0
# 8104                  10.0            0.079347                 0       0
# 10278                 14.0            0.059048                 0       0
# 289                   16.0            0.058223                 0       0
# 7864                   8.0            0.055544                 0       0

# %%
predicted_podium = specific_race_predictions.head(3)[[
    "driver_name",
    "name_constructor",
    "podium_probability",
    "positionOrder"
]]

actual_podium = specific_race_predictions[
    specific_race_predictions["podium"] == 1
][[
    "driver_name",
    "name_constructor",
    "podium_probability",
    "positionOrder"
]].sort_values("positionOrder")

print("Predicted Podium:")
display(predicted_podium)

print("Actual Podium:")
display(actual_podium)
# Out:
# Predicted Podium:
#           driver_name name_constructor  podium_probability  positionOrder
# 9632  Charles Leclerc          Ferrari            0.660849              2
# 8781     Carlos Sainz          Ferrari            0.577183              3
# 7150     Sergio Pérez         Red Bull            0.463069              4
# Actual Podium:
#           driver_name name_constructor  podium_probability  positionOrder
# 8533   Max Verstappen         Red Bull            0.190735              1
# 9632  Charles Leclerc          Ferrari            0.660849              2
# 8781     Carlos Sainz          Ferrari            0.577183              3

# %% [markdown]
# ## Row level podium accuracy

# %%
(test_with_preds["predicted_podium"] == test_with_preds["podium"]).mean()
# Out:
# np.float64(0.8977189109639441)

# %% [markdown]
# ## Row level podium accuracy

# %%
predicted_top3 = (
    test_with_preds
    .sort_values(["raceId", "podium_probability"], ascending=[True, False])
    .groupby("raceId")
    .head(3)
)

# %%
race_scores = (
    predicted_top3
    .groupby("raceId")["podium"]
    .sum()
    .reset_index()
)

race_scores = race_scores.rename(columns={"podium": "actual_podiums_found"})

race_scores.head()
# Out:
#    raceId  actual_podiums_found
# 0    1074                     2
# 1    1075                     2
# 2    1076                     2
# 3    1077                     2
# 4    1078                     3

# %%
race_scores["actual_podiums_found"].mean() / 3
# Out:
# np.float64(0.6323529411764706)

# %%
total_correct = race_scores["actual_podiums_found"].sum()
total_possible = len(race_scores) * 3

print("Total correct podium picks:", total_correct)
print("Total possible podium picks:", total_possible)
print("Percent correct:", total_correct / total_possible)
# Out:
# Total correct podium picks: 129
# Total possible podium picks: 204
# Percent correct: 0.6323529411764706

# %%
race_scores["actual_podiums_found"].value_counts().sort_index()
# Out:
# actual_podiums_found
# 0     1
# 1    17
# 2    38
# 3    12
# Name: count, dtype: int64

# %% [markdown]
#  ### Adding constructor history features did not improve the final model. The driver-history model had better ROC-AUC, F1 score, and race-level podium accuracy.
