# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
    roc_curve
)

# %% [markdown]
# ## Loading data

# %%
circuits = pd.read_csv("../data/circuits.csv")
constructor_results = pd.read_csv("../data/constructor_results.csv")
constructor_standings = pd.read_csv("../data/constructor_standings.csv")
constructors = pd.read_csv("../data/constructors.csv")
driver_standings = pd.read_csv("../data/driver_standings.csv")
drivers = pd.read_csv("../data/drivers.csv")
lap_times = pd.read_csv("../data/lap_times.csv")
pit_stops = pd.read_csv("../data/pit_stops.csv")
qualifying = pd.read_csv("../data/qualifying.csv")
races = pd.read_csv("../data/races.csv")
results = pd.read_csv("../data/results.csv")
seasons = pd.read_csv("../data/seasons.csv")
sprint_results = pd.read_csv("../data/sprint_results.csv")
status = pd.read_csv("../data/status.csv")

# %%
#sizes of the data sets and missing data
tables = {
    "circuits": circuits,
    "constructor_results": constructor_results,
    "constructor_standings": constructor_standings,
    "constructors": constructors,
    "driver_standings": driver_standings,
    "drivers": drivers,
    "lap_times": lap_times,
    "pit_stops": pit_stops,
    "qualifying": qualifying,
    "races": races,
    "results": results,
    "seasons": seasons,
    "sprint_results": sprint_results,
    "status": status
}

summary = []

for name, table in tables.items():
    summary.append({
        "table": name,
        "rows": table.shape[0],
        "columns": table.shape[1],
        "missing_values": table.isna().sum().sum()
    })

table_summary = pd.DataFrame(summary)
table_summary
# Out:
#                     table    rows  columns  missing_values
# 0                circuits      77        9               0
# 1     constructor_results   12625        5               0
# 2   constructor_standings   13391        7               0
# 3            constructors     212        5               0
# 4        driver_standings   34863        7               0
# 5                 drivers     861        9               0
# 6               lap_times  589081        6               0
# 7               pit_stops   11371        7               0
# 8              qualifying   10494        9              68
# 9                   races    1125       18               0
# 10                results   26759       18               0
# 11                seasons      75        2               0
# 12         sprint_results     360       16               0
# 13                 status     139        2               0

# %%
for name, table in tables.items():
    print(f"\n{name.upper()}")
    print(table.columns.tolist())
# Out:
# CIRCUITS
# ['circuitId', 'circuitRef', 'name', 'location', 'country', 'lat', 'lng', 'alt', 'url']
#
# CONSTRUCTOR_RESULTS
# ['constructorResultsId', 'raceId', 'constructorId', 'points', 'status']
#
# CONSTRUCTOR_STANDINGS
# ['constructorStandingsId', 'raceId', 'constructorId', 'points', 'position', 'positionText', 'wins']
#
# CONSTRUCTORS
# ['constructorId', 'constructorRef', 'name', 'nationality', 'url']
#
# DRIVER_STANDINGS
# ['driverStandingsId', 'raceId', 'driverId', 'points', 'position', 'positionText', 'wins']
#
# DRIVERS
# ['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob', 'nationality', 'url']
#
# LAP_TIMES
# ['raceId', 'driverId', 'lap', 'position', 'time', 'milliseconds']
#
# PIT_STOPS
# ['raceId', 'driverId', 'stop', 'lap', 'time', 'duration', 'milliseconds']
#
# QUALIFYING
# ['qualifyId', 'raceId', 'driverId', 'constructorId', 'number', 'position', 'q1', 'q2', 'q3']
#
# RACES
# ['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url', 'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time']
#
# RESULTS
# ['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionText', 'positionOrder', 'points', 'laps', 'time', 'milliseconds', 'fastestLap', 'rank', 'fastestLapTime', 'fastestLapSpeed', 'statusId']
#
# SEASONS
# ['year', 'url']
#
# SPRINT_RESULTS
# ['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid', 'position', 'positionText', 'positionOrder', 'points', 'laps', 'time', 'milliseconds', 'fastestLap', 'fastestLapTime', 'statusId']
#
# STATUS
# ['statusId', 'status']

# %% [markdown]
# ## Merge into one dataset

# %%
df = results.copy()

df = df.merge(races, on="raceId", how="left", suffixes=("", "_race"))
df = df.merge(drivers, on="driverId", how="left", suffixes=("", "_driver"))
df = df.merge(constructors, on="constructorId", how="left", suffixes=("", "_constructor"))
df = df.merge(circuits, on="circuitId", how="left", suffixes=("", "_circuit"))
df = df.merge(status, on="statusId", how="left")

# %%
df.shape
# Out:
# (26759, 56)

# %%
df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  ...  \
# 0            1              1    10.0  ...
# 1            2              2     8.0  ...
# 2            3              3     6.0  ...
# 3            4              4     5.0  ...
# 4            5              5     4.0  ...
#
#                                      url_constructor   circuitRef  \
# 0               http://en.wikipedia.org/wiki/McLaren  albert_park
# 1            http://en.wikipedia.org/wiki/BMW_Sauber  albert_park
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...  albert_park
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...  albert_park
# 4               http://en.wikipedia.org/wiki/McLaren  albert_park
#
#                      name_circuit   location    country      lat      lng  \
# 0  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968
# 1  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968
# 2  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968
# 3  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968
# 4  Albert Park Grand Prix Circuit  Melbourne  Australia -37.8497  144.968
#
#    alt                                        url_circuit    status
# 0   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 1   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 2   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 3   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
# 4   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Finished
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Include Qualifying Data

# %%
new_qualifying = qualifying[[
    "raceId",
    "driverId",
    "constructorId",
    "position",
    "q1",
    "q2",
    "q3"
]].copy()

new_qualifying = new_qualifying.rename(columns={
    "position": "qualifying_position"
})

df = df.merge(
    new_qualifying,
    on=["raceId", "driverId", "constructorId"],
    how="left"
)

# %% [markdown]
# ### Include Driver Standings Before Race

# %%
new_driver_standings = driver_standings[[
    "raceId",
    "driverId",
    "points",
    "position",
    "wins"
]].copy()

new_driver_standings = new_driver_standings.rename(columns={
    "points": "driver_points_after_race",
    "position": "driver_standing_after_race",
    "wins": "driver_wins_after_race"
})

df = df.merge(
    new_driver_standings,
    on=["raceId", "driverId"],
    how="left"
)

# %% [markdown]
# ### Include Constructor Standings

# %%
new_constructor_standings = constructor_standings[[
    "raceId",
    "constructorId",
    "points",
    "position",
    "wins"
]].copy()

new_constructor_standings = new_constructor_standings.rename(columns={
    "points": "constructor_points_after_race",
    "position": "constructor_standing_after_race",
    "wins": "constructor_wins_after_race"
})

df = df.merge(
    new_constructor_standings,
    on=["raceId", "constructorId"],
    how="left"
)

# %% [markdown]
# ### Inlcude Constructor Race Results

# %%
new_constructor_results = constructor_results[[
    "raceId",
    "constructorId",
    "points"
]].copy()

new_constructor_results = new_constructor_results.rename(columns={
    "points": "constructor_points_race"
})

df = df.merge(
    new_constructor_results,
    on=["raceId", "constructorId"],
    how="left"
)

# %% [markdown]
# ### Include Pit Stop
#
# - number of pit stops
# - mean times
# - total pit stop time for that race

# %%
pit_features = (
    pit_stops
    .groupby(["raceId", "driverId"])
    .agg(
        num_pit_stops=("stop", "count"),
        avg_pit_stop_ms=("milliseconds", "mean"),
        total_pit_stop_ms=("milliseconds", "sum")
    )
    .reset_index()
)

df = df.merge(
    pit_features,
    on=["raceId", "driverId"],
    how="left"
)

# %%
# fill missing times
df["num_pit_stops"] = df["num_pit_stops"].fillna(0)

# %% [markdown]
# ### Include Lap times
#
# - avg lap time
# - best lap time
# - std of lap times

# %%
lap_features = (
    lap_times
    .groupby(["raceId", "driverId"])
    .agg(
        avg_lap_ms=("milliseconds", "mean"),
        best_lap_ms=("milliseconds", "min"),
        lap_time_std_ms=("milliseconds", "std")
    )
    .reset_index()
)

df = df.merge(
    lap_features,
    on=["raceId", "driverId"],
    how="left"
)

# %% [markdown]
# ### Include Sprint Results

# %%
new_sprint = sprint_results[[
    "raceId",
    "driverId",
    "constructorId",
    "grid",
    "positionOrder",
    "points"
]].copy()

new_sprint = new_sprint.rename(columns={
    "grid": "sprint_grid",
    "positionOrder": "sprint_positionOrder",
    "points": "sprint_points"
})

df = df.merge(
    new_sprint,
    on=["raceId", "driverId", "constructorId"],
    how="left"
)

# %% [markdown]
# #### checks

# %%
df.shape
# Out:
# (26759, 76)

# %%
df.head
# Out:
# <bound method NDFrame.head of        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26754     26760    1144       825            210     20    14       16
# 26755     26761    1144       859            215     30    12       17
# 26756     26762    1144       822             15     77     9       \N
# 26757     26763    1144       861              3     43    20       \N
# 26758     26764    1144       815              9     11    10       \N
#
#       positionText  positionOrder  points  ...  constructor_points_race  \
# 0                1              1    10.0  ...                     14.0
# 1                2              2     8.0  ...                      8.0
# 2                3              3     6.0  ...                      9.0
# 3                4              4     5.0  ...                      5.0
# 4                5              5     4.0  ...                     14.0
# ...            ...            ...     ...  ...                      ...
# 26754           16             16     0.0  ...                      4.0
# 26755           17             17     0.0  ...                      0.0
# 26756            R             18     0.0  ...                      0.0
# 26757            R             19     0.0  ...                      0.0
# 26758            R             20     0.0  ...                      8.0
#
#       num_pit_stops avg_pit_stop_ms total_pit_stop_ms    avg_lap_ms  \
# 0               0.0             NaN               NaN  98114.068966
# 1               0.0             NaN               NaN  98208.517241
# 2               0.0             NaN               NaN  98254.810345
# 3               0.0             NaN               NaN  98410.293103
# 4               0.0             NaN               NaN  98424.655172
# ...             ...             ...               ...           ...
# 26754           4.0         23236.5           92946.0  92471.719298
# 26755           3.0         26099.0           78297.0  92308.163636
# 26756           1.0         41144.0           41144.0  94909.333333
# 26757           1.0         24941.0           24941.0  95016.538462
# 26758           0.0             NaN               NaN           NaN
#
#       best_lap_ms lap_time_std_ms  sprint_grid  sprint_positionOrder  \
# 0         87452.0    20990.356845          NaN                   NaN
# 1         87739.0    20212.298423          NaN                   NaN
# 2         88090.0    18957.199698          NaN                   NaN
# 3         88603.0    19640.823974          NaN                   NaN
# 4         87418.0    21826.401776          NaN                   NaN
# ...           ...             ...          ...                   ...
# 26754     85637.0     7251.481525          NaN                   NaN
# 26755     88751.0     7168.780388          NaN                   NaN
# 26756     89482.0    12734.899632          NaN                   NaN
# 26757     89411.0    10855.300667          NaN                   NaN
# 26758         NaN             NaN          NaN                   NaN
#
#        sprint_points
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 26754            NaN
# 26755            NaN
# 26756            NaN
# 26757            NaN
# 26758            NaN
#
# [26759 rows x 76 columns]>

# %%
#check 2024 Bahrain GP
races[
    (races["year"] == 2024) & (races["name"].str.contains("Bahrain", case=False, na=False))
]
# Out:
#       raceId  year  round  circuitId                name        date  \
# 1101    1121  2024      1          3  Bahrain Grand Prix  2024-03-02
#
#           time                                                url    fp1_date  \
# 1101  15:00:00  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...  2024-02-29
#
#       fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  quali_date  \
# 1101  11:30:00  2024-02-29  15:00:00  2024-03-01  12:30:00  2024-03-01
#
#      quali_time sprint_date sprint_time
# 1101   16:00:00          \N          \N

# %%
bahrain_2024_race = races[
    (races["year"] == 2024) &
    (races["name"].str.contains("Bahrain", case=False, na=False))
]

bahrain_2024_id = bahrain_2024_race["raceId"].iloc[0]

bahrain_2024_id
# Out:
# np.int64(1121)

# %%
bahrain_2024_data = df[df["raceId"] == bahrain_2024_id].copy()

# %%
bahrain_2024_clean = bahrain_2024_data[[
    "raceId",
    "year",
    "round",
    "name",
    "date",
    "driverId",
    "forename",
    "surname",
    "constructorId",
    "name_constructor",
    "grid",
    "positionOrder",
    "positionText",
    "points",
    "status",
    "qualifying_position",
    "driver_points_after_race",
    "driver_standing_after_race",
    "constructor_points_after_race",
    "constructor_standing_after_race"
]].sort_values("positionOrder")

bahrain_2024_clean
# Out:
#        raceId  year  round                name        date  driverId  \
# 26280    1121  2024      1  Bahrain Grand Prix  2024-03-02       830
# 26281    1121  2024      1  Bahrain Grand Prix  2024-03-02       815
# 26282    1121  2024      1  Bahrain Grand Prix  2024-03-02       832
# 26283    1121  2024      1  Bahrain Grand Prix  2024-03-02       844
# 26284    1121  2024      1  Bahrain Grand Prix  2024-03-02       847
# 26285    1121  2024      1  Bahrain Grand Prix  2024-03-02       846
# 26286    1121  2024      1  Bahrain Grand Prix  2024-03-02         1
# 26287    1121  2024      1  Bahrain Grand Prix  2024-03-02       857
# 26288    1121  2024      1  Bahrain Grand Prix  2024-03-02         4
# 26289    1121  2024      1  Bahrain Grand Prix  2024-03-02       840
# 26290    1121  2024      1  Bahrain Grand Prix  2024-03-02       855
# 26291    1121  2024      1  Bahrain Grand Prix  2024-03-02       825
# 26292    1121  2024      1  Bahrain Grand Prix  2024-03-02       817
# 26293    1121  2024      1  Bahrain Grand Prix  2024-03-02       852
# 26294    1121  2024      1  Bahrain Grand Prix  2024-03-02       848
# 26295    1121  2024      1  Bahrain Grand Prix  2024-03-02       807
# 26296    1121  2024      1  Bahrain Grand Prix  2024-03-02       839
# 26297    1121  2024      1  Bahrain Grand Prix  2024-03-02       842
# 26298    1121  2024      1  Bahrain Grand Prix  2024-03-02       822
# 26299    1121  2024      1  Bahrain Grand Prix  2024-03-02       858
#
#         forename     surname  constructorId name_constructor  grid  \
# 26280        Max  Verstappen              9         Red Bull     1
# 26281     Sergio       Pérez              9         Red Bull     5
# 26282     Carlos       Sainz              6          Ferrari     4
# 26283    Charles     Leclerc              6          Ferrari     2
# 26284     George     Russell            131         Mercedes     3
# 26285      Lando      Norris              1          McLaren     7
# 26286      Lewis    Hamilton            131         Mercedes     9
# 26287      Oscar     Piastri              1          McLaren     8
# 26288   Fernando      Alonso            117     Aston Martin     6
# 26289      Lance      Stroll            117     Aston Martin    12
# 26290     Guanyu        Zhou             15           Sauber    17
# 26291      Kevin   Magnussen            210     Haas F1 Team    15
# 26292     Daniel   Ricciardo            215       RB F1 Team    14
# 26293       Yuki     Tsunoda            215       RB F1 Team    11
# 26294  Alexander       Albon              3         Williams    13
# 26295       Nico  Hülkenberg            210     Haas F1 Team    10
# 26296    Esteban        Ocon            214   Alpine F1 Team    19
# 26297     Pierre       Gasly            214   Alpine F1 Team    20
# 26298   Valtteri      Bottas             15           Sauber    16
# 26299      Logan    Sargeant              3         Williams    18
#
#        positionOrder positionText  points    status  qualifying_position  \
# 26280              1            1    26.0  Finished                  1.0
# 26281              2            2    18.0  Finished                  5.0
# 26282              3            3    15.0  Finished                  4.0
# 26283              4            4    12.0  Finished                  2.0
# 26284              5            5    10.0  Finished                  3.0
# 26285              6            6     8.0  Finished                  7.0
# 26286              7            7     6.0  Finished                  9.0
# 26287              8            8     4.0  Finished                  8.0
# 26288              9            9     2.0  Finished                  6.0
# 26289             10           10     1.0  Finished                 12.0
# 26290             11           11     0.0    +1 Lap                 17.0
# 26291             12           12     0.0    +1 Lap                 15.0
# 26292             13           13     0.0    +1 Lap                 14.0
# 26293             14           14     0.0    +1 Lap                 11.0
# 26294             15           15     0.0    +1 Lap                 13.0
# 26295             16           16     0.0    +1 Lap                 10.0
# 26296             17           17     0.0    +1 Lap                 19.0
# 26297             18           18     0.0    +1 Lap                 20.0
# 26298             19           19     0.0    +1 Lap                 16.0
# 26299             20           20     0.0   +2 Laps                 18.0
#
#        driver_points_after_race  driver_standing_after_race  \
# 26280                      26.0                         1.0
# 26281                      18.0                         2.0
# 26282                      15.0                         3.0
# 26283                      12.0                         4.0
# 26284                      10.0                         5.0
# 26285                       8.0                         6.0
# 26286                       6.0                         7.0
# 26287                       4.0                         8.0
# 26288                       2.0                         9.0
# 26289                       1.0                        10.0
# 26290                       0.0                        11.0
# 26291                       0.0                        12.0
# 26292                       0.0                        13.0
# 26293                       0.0                        14.0
# 26294                       0.0                        15.0
# 26295                       0.0                        16.0
# 26296                       0.0                        17.0
# 26297                       0.0                        18.0
# 26298                       0.0                        19.0
# 26299                       0.0                        20.0
#
#        constructor_points_after_race  constructor_standing_after_race
# 26280                           44.0                              1.0
# 26281                           44.0                              1.0
# 26282                           27.0                              2.0
# 26283                           27.0                              2.0
# 26284                           16.0                              3.0
# 26285                           12.0                              4.0
# 26286                           16.0                              3.0
# 26287                           12.0                              4.0
# 26288                            3.0                              5.0
# 26289                            3.0                              5.0
# 26290                            0.0                              6.0
# 26291                            0.0                              7.0
# 26292                            0.0                              8.0
# 26293                            0.0                              8.0
# 26294                            0.0                              9.0
# 26295                            0.0                              7.0
# 26296                            0.0                             10.0
# 26297                            0.0                             10.0
# 26298                            0.0                              6.0
# 26299                            0.0                              9.0

# %%
import os

os.makedirs("../data/processed", exist_ok=True)

df.to_csv("../data/processed/f1_full_merged_dataset.csv", index=False)

# %% [markdown]
# ## Target variable

# %%
df["podium"] = (df["positionOrder"] <= 3).astype(int)

df["podium_place"] = np.where(
    df["positionOrder"] <= 3,
    df["positionOrder"],
    np.nan
)

# %%
df["podium"].value_counts()
df["podium"].value_counts(normalize=True)
# Out:
# podium
# 0    0.873052
# 1    0.126948
# Name: proportion, dtype: float64

# %% [markdown]
# ## Before Race Standings
#
# Some variables in this dataset are only known during or after race, such as final position, points, pit stops, lap times, race status, fastest lap information, and race-level constructor points. These variables will not be used in the final pre-race prediction model because they would cause data leakage.

# %%
#driver 

df = df.sort_values(["driverId", "year", "round"])

df["driver_points_before_race"] = (
    df.groupby(["driverId", "year"])["driver_points_after_race"]
    .shift(1)
)

df["driver_standing_before_race"] = (
    df.groupby(["driverId", "year"])["driver_standing_after_race"]
    .shift(1)
)

df["driver_wins_before_race"] = (
    df.groupby(["driverId", "year"])["driver_wins_after_race"]
    .shift(1)
)

df["driver_standing_before_race"] = df["driver_standing_before_race"].fillna(99)

# %%
#contructor, corrected for 2 drivers in same race

constructor_race = (
    df[[
        "constructorId",
        "year",
        "round",
        "raceId",
        "constructor_points_after_race",
        "constructor_standing_after_race",
        "constructor_wins_after_race"
    ]]
    .drop_duplicates()
    .sort_values(["constructorId", "year", "round"])
)

constructor_race["constructor_points_before_race"] = (
    constructor_race.groupby(["constructorId", "year"])["constructor_points_after_race"]
    .shift(1)
)

constructor_race["constructor_standing_before_race"] = (
    constructor_race.groupby(["constructorId", "year"])["constructor_standing_after_race"]
    .shift(1)
)

constructor_race["constructor_wins_before_race"] = (
    constructor_race.groupby(["constructorId", "year"])["constructor_wins_after_race"]
    .shift(1)
)

constructor_race["constructor_points_before_race"] = constructor_race["constructor_points_before_race"].fillna(0)
constructor_race["constructor_wins_before_race"] = constructor_race["constructor_wins_before_race"].fillna(0)
constructor_race["constructor_standing_before_race"] = constructor_race["constructor_standing_before_race"].fillna(99)

df = df.drop(columns=[
    "constructor_points_before_race",
    "constructor_standing_before_race",
    "constructor_wins_before_race"
], errors="ignore")

df = df.merge(
    constructor_race[[
        "constructorId",
        "raceId",
        "constructor_points_before_race",
        "constructor_standing_before_race",
        "constructor_wins_before_race"
    ]],
    on=["constructorId", "raceId"],
    how="left"
)

# %%
#missing values
df["driver_points_before_race"] = df["driver_points_before_race"].fillna(0)
df["driver_wins_before_race"] = df["driver_wins_before_race"].fillna(0)

df["constructor_points_before_race"] = df["constructor_points_before_race"].fillna(0)
df["constructor_wins_before_race"] = df["constructor_wins_before_race"].fillna(0)

# %%
#check 
bahrain_2024 = df[(df["year"] == 2024) & (df["round"] == 1)].copy()

bahrain_2024[[
    "raceId",
    "year",
    "round",
    "driverId",
    "forename",
    "surname",
    "constructorId",
    "name_constructor",
    "grid",
    "positionOrder",
    "podium",
    "driver_points_before_race",
    "driver_points_after_race",
    "driver_standing_before_race",
    "driver_standing_after_race",
    "constructor_points_before_race",
    "constructor_points_after_race",
    "constructor_standing_before_race",
    "constructor_standing_after_race"
]].sort_values("positionOrder")
# Out:
#        raceId  year  round  driverId   forename     surname  constructorId  \
# 24838    1121  2024      1       830        Max  Verstappen              9
# 23446    1121  2024      1       815     Sergio       Pérez              9
# 25087    1121  2024      1       832     Carlos       Sainz              6
# 25948    1121  2024      1       844    Charles     Leclerc              6
# 26225    1121  2024      1       847     George     Russell            131
# 26097    1121  2024      1       846      Lando      Norris              1
# 332      1121  2024      1         1      Lewis    Hamilton            131
# 26675    1121  2024      1       857      Oscar     Piastri              1
# 1126     1121  2024      1         4   Fernando      Alonso            117
# 25558    1121  2024      1       840      Lance      Stroll            117
# 26618    1121  2024      1       855     Guanyu        Zhou             15
# 24402    1121  2024      1       825      Kevin   Magnussen            210
# 23729    1121  2024      1       817     Daniel   Ricciardo            215
# 26484    1121  2024      1       852       Yuki     Tsunoda            215
# 26330    1121  2024      1       848  Alexander       Albon              3
# 22874    1121  2024      1       807       Nico  Hülkenberg            210
# 25391    1121  2024      1       839    Esteban        Ocon            214
# 25774    1121  2024      1       842     Pierre       Gasly            214
# 24161    1121  2024      1       822   Valtteri      Bottas             15
# 26721    1121  2024      1       858      Logan    Sargeant              3
#
#       name_constructor  grid  positionOrder  podium  \
# 24838         Red Bull     1              1       1
# 23446         Red Bull     5              2       1
# 25087          Ferrari     4              3       1
# 25948          Ferrari     2              4       0
# 26225         Mercedes     3              5       0
# 26097          McLaren     7              6       0
# 332           Mercedes     9              7       0
# 26675          McLaren     8              8       0
# 1126      Aston Martin     6              9       0
# 25558     Aston Martin    12             10       0
# 26618           Sauber    17             11       0
# 24402     Haas F1 Team    15             12       0
# 23729       RB F1 Team    14             13       0
# 26484       RB F1 Team    11             14       0
# 26330         Williams    13             15       0
# 22874     Haas F1 Team    10             16       0
# 25391   Alpine F1 Team    19             17       0
# 25774   Alpine F1 Team    20             18       0
# 24161           Sauber    16             19       0
# 26721         Williams    18             20       0
#
#        driver_points_before_race  driver_points_after_race  \
# 24838                        0.0                      26.0
# 23446                        0.0                      18.0
# 25087                        0.0                      15.0
# 25948                        0.0                      12.0
# 26225                        0.0                      10.0
# 26097                        0.0                       8.0
# 332                          0.0                       6.0
# 26675                        0.0                       4.0
# 1126                         0.0                       2.0
# 25558                        0.0                       1.0
# 26618                        0.0                       0.0
# 24402                        0.0                       0.0
# 23729                        0.0                       0.0
# 26484                        0.0                       0.0
# 26330                        0.0                       0.0
# 22874                        0.0                       0.0
# 25391                        0.0                       0.0
# 25774                        0.0                       0.0
# 24161                        0.0                       0.0
# 26721                        0.0                       0.0
#
#        driver_standing_before_race  driver_standing_after_race  \
# 24838                         99.0                         1.0
# 23446                         99.0                         2.0
# 25087                         99.0                         3.0
# 25948                         99.0                         4.0
# 26225                         99.0                         5.0
# 26097                         99.0                         6.0
# 332                           99.0                         7.0
# 26675                         99.0                         8.0
# 1126                          99.0                         9.0
# 25558                         99.0                        10.0
# 26618                         99.0                        11.0
# 24402                         99.0                        12.0
# 23729                         99.0                        13.0
# 26484                         99.0                        14.0
# 26330                         99.0                        15.0
# 22874                         99.0                        16.0
# 25391                         99.0                        17.0
# 25774                         99.0                        18.0
# 24161                         99.0                        19.0
# 26721                         99.0                        20.0
#
#        constructor_points_before_race  constructor_points_after_race  \
# 24838                             0.0                           44.0
# 23446                             0.0                           44.0
# 25087                             0.0                           27.0
# 25948                             0.0                           27.0
# 26225                             0.0                           16.0
# 26097                             0.0                           12.0
# 332                               0.0                           16.0
# 26675                             0.0                           12.0
# 1126                              0.0                            3.0
# 25558                             0.0                            3.0
# 26618                             0.0                            0.0
# 24402                             0.0                            0.0
# 23729                             0.0                            0.0
# 26484                             0.0                            0.0
# 26330                             0.0                            0.0
# 22874                             0.0                            0.0
# 25391                             0.0                            0.0
# 25774                             0.0                            0.0
# 24161                             0.0                            0.0
# 26721                             0.0                            0.0
#
#        constructor_standing_before_race  constructor_standing_after_race
# 24838                              99.0                              1.0
# 23446                              99.0                              1.0
# 25087                              99.0                              2.0
# 25948                              99.0                              2.0
# 26225                              99.0                              3.0
# 26097                              99.0                              4.0
# 332                                99.0                              3.0
# 26675                              99.0                              4.0
# 1126                               99.0                              5.0
# 25558                              99.0                              5.0
# 26618                              99.0                              6.0
# 24402                              99.0                              7.0
# 23729                              99.0                              8.0
# 26484                              99.0                              8.0
# 26330                              99.0                              9.0
# 22874                              99.0                              7.0
# 25391                              99.0                             10.0
# 25774                              99.0                             10.0
# 24161                              99.0                              6.0
# 26721                              99.0                              9.0

# %% [markdown]
# Bahrain 2024 is the first race of the season, all before-race points are 0 and before-race standings are filled with 99 because no season andings existed before Round 1. The after-race columns reflect the actual results from the race, so they are not used as predictors.

# %% [markdown]
# ## EDA

# %%
#podium vs non-podium distribution
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="podium")

plt.title("Podium vs Non-Podium Finishes")
plt.xlabel("Podium Finish")
plt.ylabel("Number of Driver-Race Rows")
plt.show()

# %% [markdown]
# Analysis

# %%
#podium rate by starting grid position
grid_podium = df.groupby("grid")["podium"].mean().reset_index()

plt.figure(figsize=(8,4))

sns.lineplot(data=grid_podium, x="grid", y="podium")

plt.title("Podium Rate by Starting Grid Position")
plt.xlabel("Starting Grid Position")
plt.ylabel("Podium Rate")
plt.show()

# %%
#Podium rate by qualifying position
qual_podium = df.groupby("qualifying_position")["podium"].mean().reset_index()

plt.figure(figsize=(8,4))

sns.lineplot(data=qual_podium, x="qualifying_position", y="podium")

plt.title("Podium Rate by Qualifying Position")
plt.xlabel("Qualifying Position")
plt.ylabel("Podium Rate")
plt.show()

# %%
#Top constructors by podium rate
constructor_podium = (
    df.groupby("name_constructor")["podium"]
    .agg(["count", "mean"])
    .reset_index()
)

constructor_podium = constructor_podium[constructor_podium["count"] >= 100]

constructor_podium = constructor_podium.sort_values("mean", ascending=False).head(15)

plt.figure(figsize=(10,5))

sns.barplot(data=constructor_podium, x="mean", y="name_constructor")

plt.title("Top Constructors by Podium Rate")
plt.xlabel("Podium Rate")
plt.ylabel("Constructor")
plt.show()

# %%
#Top drivers by podium rate
df["driver_name"] = df["forename"] + " " + df["surname"]

driver_podium = (
    df.groupby("driver_name")["podium"]
    .agg(["count", "mean"])
    .reset_index()
)

driver_podium = driver_podium[driver_podium["count"] >= 50]

driver_podium = driver_podium.sort_values("mean", ascending=False).head(15)

plt.figure(figsize=(10,5))

sns.barplot(data=driver_podium, x="mean", y="driver_name")

plt.title("Top Drivers by Podium Rate")
plt.xlabel("Podium Rate")
plt.ylabel("Driver")
plt.show()

# %%
#Podium rate by year
year_podium = df.groupby("year")["podium"].mean().reset_index()

plt.figure(figsize=(10,4))

sns.lineplot(data=year_podium, x="year", y="podium")

plt.title("Podium Rate by Year")
plt.xlabel("Year")
plt.ylabel("Podium Rate")
plt.show()

# %%
#Points before race vs podium
plt.figure(figsize=(8,4))

sns.boxplot(data=df, x="podium", y="driver_points_before_race")

plt.title("Driver Points Before Race vs Podium")
plt.xlabel("Podium Finish")
plt.ylabel("Driver Points Before Race")
plt.show()

# %%
#Constructor points before race vs podium
plt.figure(figsize=(8,4))

sns.boxplot(data=df, x="podium", y="constructor_points_before_race")

plt.title("Constructor Points Before Race vs Podium")
plt.xlabel("Podium Finish")
plt.ylabel("Constructor Points Before Race")
plt.show()

# %%
#Missing values check
missing = df.isna().sum().sort_values(ascending=False)

missing[missing > 0].head(20)
# Out:
# sprint_grid                        26399
# sprint_points                      26399
# sprint_positionOrder               26399
# podium_place                       23362
# avg_pit_stop_ms                    21184
# total_pit_stop_ms                  21184
# q3                                 16321
# q2                                 16297
# qualifying_position                16275
# q1                                 16275
# lap_time_std_ms                    15833
# best_lap_ms                        15718
# avg_lap_ms                         15718
# constructor_standing_after_race     1867
# constructor_wins_after_race         1867
# constructor_points_after_race       1867
# constructor_points_race             1611
# driver_wins_after_race               469
# driver_points_after_race             469
# driver_standing_after_race           469
# dtype: int64

# %%
df.to_csv("../data/processed/f1_full_merged_dataset.csv", index=False)
