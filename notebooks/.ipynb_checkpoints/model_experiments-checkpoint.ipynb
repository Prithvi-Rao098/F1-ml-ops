# %% [markdown]
# # Feature Set Experiments
#
# ADD section

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
df = pd.read_csv("../data/processed/f1_full_merged_dataset.csv", low_memory=False)

df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0       371      36         1              1      2     4        3
# 1       392      37         1              1      2     4        2
# 2       414      38         1              1      2     2        2
# 3       436      39         1              1      2     4        2
# 4       458      40         1              1      2     2        2
#
#   positionText  positionOrder  points  ...  sprint_points podium podium_place  \
# 0            3              3     6.0  ...            NaN      1          3.0
# 1            2              2     8.0  ...            NaN      1          2.0
# 2            2              2     8.0  ...            NaN      1          2.0
# 3            2              2     8.0  ...            NaN      1          2.0
# 4            2              2     8.0  ...            NaN      1          2.0
#
#   driver_points_before_race driver_standing_before_race  \
# ...

# %%
modeling_data = df[[
    "raceId",
    "driverId",
    "driver_name",
    "constructorId",
    "name_constructor",
    "circuitId",
    "year",
    "round",
    "grid",
    "qualifying_position",
    "driver_points_before_race",
    "driver_standing_before_race",
    "driver_wins_before_race",
    "constructor_points_before_race",
    "constructor_standing_before_race",
    "constructor_wins_before_race",
    "podium"
]].copy()

modeling_data.head()
# Out:
#    raceId  driverId     driver_name  constructorId name_constructor  \
# 0      36         1  Lewis Hamilton              1          McLaren
# 1      37         1  Lewis Hamilton              1          McLaren
# 2      38         1  Lewis Hamilton              1          McLaren
# 3      39         1  Lewis Hamilton              1          McLaren
# 4      40         1  Lewis Hamilton              1          McLaren
#
#    circuitId  year  round  grid  qualifying_position  \
# 0          1  2007      1     4                  4.0
# 1          2  2007      2     4                  4.0
# 2          3  2007      3     2                  2.0
# 3          4  2007      4     4                  4.0
# 4          6  2007      5     2                  2.0
#
#    driver_points_before_race  driver_standing_before_race  \
# 0                        0.0                         99.0
# 1                        6.0                          3.0
# ...

# %%
modeling_data.isna().sum()
# Out:
# raceId                                  0
# driverId                                0
# driver_name                             0
# constructorId                           0
# name_constructor                        0
# circuitId                               0
# year                                    0
# round                                   0
# grid                                    0
# qualifying_position                 16275
# driver_points_before_race               0
# driver_standing_before_race             0
# driver_wins_before_race                 0
# constructor_points_before_race          0
# constructor_standing_before_race        0
# constructor_wins_before_race            0
# podium                                  0
# dtype: int64

# %%
modeling_data.shape
# Out:
# (26759, 17)

# %%
modeling_data = modeling_data.dropna()

modeling_data.shape
# Out:
# (10484, 17)

# %%
modeling_data["podium"].value_counts()
# Out:
# podium
# 0    9002
# 1    1482
# Name: count, dtype: int64

# %%
modeling_data["podium"].value_counts(normalize=True)
# Out:
# podium
# 0    0.858642
# 1    0.141358
# Name: proportion, dtype: float64

# %% [markdown]
# ## Train, Validation and Test sets

# %%
train = modeling_data[modeling_data["year"] <= 2018]

val = modeling_data[
    (modeling_data["year"] >= 2019) &
    (modeling_data["year"] <= 2021)
]

test = modeling_data[modeling_data["year"] >= 2022]

# %%
print("Train shape:", train.shape)
print("Validation shape:", val.shape)
print("Test shape:", test.shape)
# Out:
# Train shape: (7928, 17)
# Validation shape: (1197, 17)
# Test shape: (1359, 17)

# %% [markdown]
# ### Feature sets

# %%
feature_sets = {
    
    "grid_only": [
        "grid"
    ],
    
    "grid_and_qualifying": [
        "grid",
        "qualifying_position"
    ],
    
    "race_context": [
        "grid",
        "qualifying_position",
        "year",
        "round",
        "circuitId"
    ],
    
    "driver_constructor_circuit": [
        "grid",
        "qualifying_position",
        "driverId",
        "constructorId",
        "circuitId"
    ],
    
    "standings_only": [
        "grid",
        "qualifying_position",
        "driver_points_before_race",
        "driver_standing_before_race",
        "driver_wins_before_race",
        "constructor_points_before_race",
        "constructor_standing_before_race",
        "constructor_wins_before_race"
    ],
    
    "all_valid_features": [
        "driverId",
        "constructorId",
        "circuitId",
        "year",
        "round",
        "grid",
        "qualifying_position",
        "driver_points_before_race",
        "driver_standing_before_race",
        "driver_wins_before_race",
        "constructor_points_before_race",
        "constructor_standing_before_race",
        "constructor_wins_before_race"
    ]
}

# %% [markdown]
# ## Feature Set 1: grid_only
# - Logistic Regression
# - Random Forest
# - Gradient Boosting

# %%
features = ["grid"]

X_train = train[features]
Y_train = train["podium"]

X_val = val[features]
Y_val = val["podium"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
model_results = []

# %% [markdown]
# #### Logistic Regression

# %%
lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, Y_train)

lr_preds = lr_model.predict(X_val)
lr_probs = lr_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_only",
    "model": "Logistic Regression",
    "accuracy": accuracy_score(Y_val, lr_preds),
    "precision": precision_score(Y_val, lr_preds, zero_division=0),
    "recall": recall_score(Y_val, lr_preds, zero_division=0),
    "f1": f1_score(Y_val, lr_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, lr_probs)
})

# %% [markdown]
# #### Random Forest

# %%
rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, Y_train)

rf_preds = rf_model.predict(X_val)
rf_probs = rf_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_only",
    "model": "Random Forest",
    "accuracy": accuracy_score(Y_val, rf_preds),
    "precision": precision_score(Y_val, rf_preds, zero_division=0),
    "recall": recall_score(Y_val, rf_preds, zero_division=0),
    "f1": f1_score(Y_val, rf_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, rf_probs)
})

# %% [markdown]
# #### Gradient Boosting

# %%
gb_model = GradientBoostingClassifier(random_state=42)

gb_model.fit(X_train, Y_train)

gb_preds = gb_model.predict(X_val)
gb_probs = gb_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_only",
    "model": "Gradient Boosting",
    "accuracy": accuracy_score(Y_val, gb_preds),
    "precision": precision_score(Y_val, gb_preds, zero_division=0),
    "recall": recall_score(Y_val, gb_preds, zero_division=0),
    "f1": f1_score(Y_val, gb_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, gb_probs)
})

# %%
results_df = pd.DataFrame(model_results)

results_df
# Out:
#   feature_set                model  accuracy  precision    recall        f1  \
# 0   grid_only  Logistic Regression  0.878028   0.614865  0.505556  0.554878
# 1   grid_only        Random Forest  0.901420   0.758333  0.505556  0.606667
# 2   grid_only    Gradient Boosting  0.901420   0.758333  0.505556  0.606667
#
#     roc_auc
# 0  0.889405
# 1  0.917614
# 2  0.918581

# %% [markdown]
# Looking the model performance for just starting grid position, we can see that are capturing ~51% of actual podium finishes. In addition the ROC accuracy is around 90%, which makes starting grid position a really strong predictor.

# %% [markdown]
# ## Feature Set 2: Grid + Qualifying
#
# - Logistic Regression
# - Random Forest
# - Gradient Boosting
#
# features = ["grid", "qualifying_position"]

# %%
features = ["grid", "qualifying_position"]

X_train = train[features]
Y_train = train["podium"]

X_val = val[features]
Y_val = val["podium"]

# %% [markdown]
# #### Logistic Regression

# %%
lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, Y_train)

lr_preds = lr_model.predict(X_val)
lr_probs = lr_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_qualifying",
    "model": "Logistic Regression",
    "accuracy": accuracy_score(Y_val, lr_preds),
    "precision": precision_score(Y_val, lr_preds, zero_division=0),
    "recall": recall_score(Y_val, lr_preds, zero_division=0),
    "f1": f1_score(Y_val, lr_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, lr_probs)
})

# %% [markdown]
# #### Random Foresst

# %%
rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, Y_train)

rf_preds = rf_model.predict(X_val)
rf_probs = rf_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_qualifying",
    "model": "Random Forest",
    "accuracy": accuracy_score(Y_val, rf_preds),
    "precision": precision_score(Y_val, rf_preds, zero_division=0),
    "recall": recall_score(Y_val, rf_preds, zero_division=0),
    "f1": f1_score(Y_val, rf_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, rf_probs)
})

# %% [markdown]
# #### Gradient Boosting

# %%
gb_model = GradientBoostingClassifier(random_state=42)

gb_model.fit(X_train, Y_train)

gb_preds = gb_model.predict(X_val)
gb_probs = gb_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "grid_qualifying",
    "model": "Gradient Boosting",
    "accuracy": accuracy_score(Y_val, gb_preds),
    "precision": precision_score(Y_val, gb_preds, zero_division=0),
    "recall": recall_score(Y_val, gb_preds, zero_division=0),
    "f1": f1_score(Y_val, gb_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, gb_probs)
})

# %%
results_df = pd.DataFrame(model_results)

results_df.sort_values("roc_auc", ascending=False)
# Out:
#        feature_set                model  accuracy  precision    recall  \
# 3  grid_qualifying  Logistic Regression  0.895572   0.735043  0.477778
# 4  grid_qualifying        Random Forest  0.908939   0.715152  0.655556
# 2        grid_only    Gradient Boosting  0.901420   0.758333  0.505556
# 1        grid_only        Random Forest  0.901420   0.758333  0.505556
# 5  grid_qualifying    Gradient Boosting  0.907268   0.711656  0.644444
# 0        grid_only  Logistic Regression  0.878028   0.614865  0.505556
#
#          f1   roc_auc
# 3  0.579125  0.921670
# 4  0.684058  0.919496
# 2  0.606667  0.918581
# 1  0.606667  0.917614
# 5  0.676385  0.911958
# 0  0.554878  0.889405

# %% [markdown]
# ## Feature Set 3: Driver History
# - Logistic Regression
# - Random Forest
# - Gradient Boosting
#
# features = [
#     "grid",
#     "qualifying_position",
#     "driver_points_before_race",
#     "driver_standing_before_race",
#     "driver_wins_before_race"
# ]

# %%
features = [
    "grid",
    "qualifying_position",
    "driver_points_before_race",
    "driver_standing_before_race",
    "driver_wins_before_race"
]

X_train = train[features]
Y_train = train["podium"]

X_val = val[features]
Y_val = val["podium"]

# %% [markdown]
# #### Logistic Regression

# %%
lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, Y_train)

lr_preds = lr_model.predict(X_val)
lr_probs = lr_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "driver_history",
    "model": "Logistic Regression",
    "accuracy": accuracy_score(Y_val, lr_preds),
    "precision": precision_score(Y_val, lr_preds, zero_division=0),
    "recall": recall_score(Y_val, lr_preds, zero_division=0),
    "f1": f1_score(Y_val, lr_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, lr_probs)
})

# %% [markdown]
# #### Random Forest

# %%
rf_model = RandomForestClassifier(random_state=42)

rf_model.fit(X_train, Y_train)

rf_preds = rf_model.predict(X_val)
rf_probs = rf_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "driver_history",
    "model": "Random Forest",
    "accuracy": accuracy_score(Y_val, rf_preds),
    "precision": precision_score(Y_val, rf_preds, zero_division=0),
    "recall": recall_score(Y_val, rf_preds, zero_division=0),
    "f1": f1_score(Y_val, rf_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, rf_probs)
})

# %% [markdown]
# #### Gradient Boosting

# %%
gb_model = GradientBoostingClassifier(random_state=42)

gb_model.fit(X_train, Y_train)

gb_preds = gb_model.predict(X_val)
gb_probs = gb_model.predict_proba(X_val)[:, 1]

model_results.append({
    "feature_set": "driver_history",
    "model": "Gradient Boosting",
    "accuracy": accuracy_score(Y_val, gb_preds),
    "precision": precision_score(Y_val, gb_preds, zero_division=0),
    "recall": recall_score(Y_val, gb_preds, zero_division=0),
    "f1": f1_score(Y_val, gb_preds, zero_division=0),
    "roc_auc": roc_auc_score(Y_val, gb_probs)
})

# %%
results_df = pd.DataFrame(model_results)

results_df.sort_values("roc_auc", ascending=False)
# Out:
#        feature_set                model  accuracy  precision    recall  \
# 8   driver_history    Gradient Boosting  0.923141   0.761905  0.711111
# 6   driver_history  Logistic Regression  0.904762   0.732394  0.577778
# 3  grid_qualifying  Logistic Regression  0.895572   0.735043  0.477778
# 4  grid_qualifying        Random Forest  0.908939   0.715152  0.655556
# 2        grid_only    Gradient Boosting  0.901420   0.758333  0.505556
# 1        grid_only        Random Forest  0.901420   0.758333  0.505556
# 5  grid_qualifying    Gradient Boosting  0.907268   0.711656  0.644444
# 7   driver_history        Random Forest  0.893901   0.670968  0.577778
# 0        grid_only  Logistic Regression  0.878028   0.614865  0.505556
#
#          f1   roc_auc
# 8  0.735632  0.934207
# 6  0.645963  0.925563
# 3  0.579125  0.921670
# 4  0.684058  0.919496
# 2  0.606667  0.918581
# 1  0.606667  0.917614
# 5  0.676385  0.911958
# 7  0.620896  0.902753
# 0  0.554878  0.889405

# %% [markdown]
# ## Rest of featurs added to model_results list

# %%
remaining_feature_sets = {

    "constructor_history": [
        "grid",
        "qualifying_position",
        "constructor_points_before_race",
        "constructor_standing_before_race",
        "constructor_wins_before_race"
    ],

    "all_valid_features": [
        "driverId",
        "constructorId",
        "circuitId",
        "year",
        "round",
        "grid",
        "qualifying_position",
        "driver_points_before_race",
        "driver_standing_before_race",
        "driver_wins_before_race",
        "constructor_points_before_race",
        "constructor_standing_before_race",
        "constructor_wins_before_race"
    ]
}

# %%
models = {

    #fix for scaling issues
    "Logistic Regression": make_pipeline(
        StandardScaler(),
        LogisticRegression(max_iter=5000)
    ),
    
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42)
}

# %%
def test_model(model, model_name, feature_set_name, features):
    
    X_train = train[features]
    Y_train = train["podium"]

    X_val = val[features]
    Y_val = val["podium"]

    model.fit(X_train, Y_train)

    preds = model.predict(X_val)
    probs = model.predict_proba(X_val)[:, 1]

    result = {
        "feature_set": feature_set_name,
        "model": model_name,
        "accuracy": accuracy_score(Y_val, preds),
        "precision": precision_score(Y_val, preds, zero_division=0),
        "recall": recall_score(Y_val, preds, zero_division=0),
        "f1": f1_score(Y_val, preds, zero_division=0),
        "roc_auc": roc_auc_score(Y_val, probs)
    }

    return result

# %%
for feature_set_name, features in remaining_feature_sets.items():

    for model_name, model in models.items():

        result = test_model(
            model,
            model_name,
            feature_set_name,
            features
        )

        model_results.append(result)

# %%
results_df = pd.DataFrame(model_results)

results_df.sort_values("roc_auc", ascending=False)
# Out:
#             feature_set                model  accuracy  precision    recall  \
# 8        driver_history    Gradient Boosting  0.923141   0.761905  0.711111
# 14   all_valid_features    Gradient Boosting  0.910610   0.735484  0.633333
# 11  constructor_history    Gradient Boosting  0.905597   0.721854  0.605556
# 12   all_valid_features  Logistic Regression  0.902256   0.752000  0.522222
# 6        driver_history  Logistic Regression  0.904762   0.732394  0.577778
# 13   all_valid_features        Random Forest  0.904762   0.717105  0.605556
# 9   constructor_history  Logistic Regression  0.898079   0.701389  0.561111
# 3       grid_qualifying  Logistic Regression  0.895572   0.735043  0.477778
# 4       grid_qualifying        Random Forest  0.908939   0.715152  0.655556
# 2             grid_only    Gradient Boosting  0.901420   0.758333  0.505556
# 1             grid_only        Random Forest  0.901420   0.758333  0.505556
# ...

# %% [markdown]
# Comparing the combination of feature set and the three models, we can see that the best performing model is Gradient Boosting based on the driver_history feature set. This is interesting because it seems like training on all valid features doesn't necessarily mean best performance.  ADD MORE ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="roc_auc",
    y="feature_set",
    hue="model"
)

plt.title("Model Comparison by ROC-AUC")
plt.xlabel("ROC-AUC")
plt.ylabel("Feature Set")
plt.show()

# %%
modeling_data.to_csv("../data/processed/f1_modeling_dataset.csv", index=False)

results_df.to_csv("../data/processed/model_experiment_results.csv", index=False)
